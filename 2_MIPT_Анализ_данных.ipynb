# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammadsulton1/MIPT_Data_analys/blob/main/2_MIPT_%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('mpg.csv')

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  ...  model_year  origin                       name
# 0  18.0          8         307.0  ...          70     usa  chevrolet chevelle malibu
# 1  15.0          8         350.0  ...          70     usa          buick skylark 320
# 2  18.0          8         318.0  ...          70     usa         plymouth satellite
# 3  16.0          8         304.0  ...          70     usa              amc rebel sst
# 4  17.0          8         302.0  ...          70     usa                ford torino
#
# [5 rows x 9 columns]

# %%
data[['mpg','cylinders','horsepower']]
# Out:
#       mpg  cylinders  horsepower
# 0    18.0          8       130.0
# 1    15.0          8       165.0
# 2    18.0          8       150.0
# 3    16.0          8       150.0
# 4    17.0          8       140.0
# ..    ...        ...         ...
# 393  27.0          4        86.0
# 394  44.0          4        52.0
# 395  32.0          4        84.0
# 396  28.0          4        79.0
# 397  31.0          4        82.0
#
# [398 rows x 3 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(data.iloc[:,0:6],height=2.5,kind='scatter');

# %%
#mpg  --> liters per 100 km
mile = 1.609 #km
gallon = 3.785 #l
inch = 2.54 #cm
lbs = 0.4536 #kg

# %%
data['lpk'] = mile * gallon * 100 / data['mpg']

# %%
data['env'] = data['displacement'] * inch**3 / 1000 #motor

# %%
data['mass'] = data['weight'] * lbs / 1000 # с тоннами

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  ...        lpk       env      mass
# 0  18.0          8         307.0  ...  33.833694  5.030829  1.589414
# 1  15.0          8         350.0  ...  40.600433  5.735472  1.675145
# 2  18.0          8         318.0  ...  33.833694  5.211086  1.558570
# 3  16.0          8         304.0  ...  38.062906  4.981667  1.557209
# 4  17.0          8         302.0  ...  35.823912  4.948893  1.564466
#
# [5 rows x 12 columns]

# %%
new_par = ['cylinders','horsepower','acceleration','lpk']
